# %%
import numpy as np
import pandas as pd

# %%
coordinates = pd.DataFrame({
    'x': np.random.uniform(0, 100, 10),
    'y': np.random.uniform(0, 100, 10)
})

print(coordinates)
# Out:
#            x          y
# 0  98.535298  81.550994
# 1  97.225636  61.156176
# 2  46.527321  84.400064
# 3  20.143410  24.973971
# 4  99.128487  15.327340
# 5  80.888249  89.282647
# 6   5.148265  11.650955
# 7   1.884405  87.959816
# 8  44.566953  89.902660
# 9  24.013212  96.918078
